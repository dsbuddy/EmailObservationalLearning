# %%
from dateutil import parser
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re
import random
import json

# %%
def processData(filename, separator):
    data = pd.read_csv(filename, sep=separator) 
    data["Timestamp"] = [parser.parse(x) for x in data["Timestamp"]]
    data.sort_values(by=['Sender', 'Timestamp'])
    return data

# %%
def extractEmail(sender):
    if '<' in sender:
        return re.search(r'<(.+)>', sender).group(1)
    return sender

# %%
def isNew(df, idx1, idx2):
    if df['Sender'][idx1] != df['Sender'][idx2]:
        return True
    if (df['Timestamp'][idx2] - df['Timestamp'][idx1]).total_seconds() > 40:
        return True
    return False

# %%
def addEmbedding(senders, sender, transitions):
    if sender not in senders:
        senders[sender] = []
    senders[sender].append(transitions)

# %%
def analyzeSenderActivity(df):
    senders = {}
    prevIdx = df.index[0]
    transitions = [df['Action'][0]]


    for currIdx in df.index[1:]:
        sender = extractEmail(df['Sender'][currIdx])
        
        if isNew(df, prevIdx, currIdx):
            if prevSender not in senders:
                senders[prevSender] = []
            # senders[prevSender].append(transitions)
            senders[prevSender].append(" -> ".join(transitions))
            transitions = []
            
        action = df['Action'][currIdx]
        if action == 'DURATION':
            transitions.append('OPEN')
            transitions.append('CLOSED')
            transitions.append('DURATION')
        elif action == 'ENGAGED' and action in transitions:
            continue
        else:
            transitions.append(action)

        prevIdx = currIdx
        prevSender = sender

    return senders

# %%
def stripToLastActivity(senders):
    lastUpdated = {}
    for key, value in senders.items():
        lastUpdated[key] = value[-1]
        
    return lastUpdated

# %%
def stripMostCommonActivity(senders):
    lastUpdated = {}
    for key, value in senders.items():
        lastUpdated[key] = max(set(value), key=value.count)
        
    return lastUpdated

# %%
def cluster(d):
    flipped = {} 

    for key, value in d.items(): 
        if value not in flipped: 
            flipped[value] = [key] 
        else: 
            flipped[value].append(key) 

    return flipped

# %%
# df = processData('tmp.csv', '{')
df = processData('tabbed.csv', '\t')
senders = analyzeSenderActivity(df)
print(json.dumps(senders, indent=1))
# Out:
# {
#  "messages-noreply@linkedin.com": [
#   "FROM -> SUBJECT -> DATE -> OPEN -> CLOSED -> DURATION -> ENGAGED",
#   "FROM -> DELETE"
#  ],
#  "chestnutsquare@studenthousing.com": [
#   "FROM",
#   "SUBJECT -> DATE -> ENGAGED",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "no-reply@jumpstart.me": [
#   "FROM -> DELETE",
#   "FROM",
#   "DELETE",
#   "FROM -> DELETE"
#  ],
#  "paypal@mail.paypal.com": [
#   "FROM -> SUBJECT -> DATE -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "OliveGarden@e.olivegarden.com": [
#   "FROM -> DATE -> SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> ENGAGED",
#   "DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "mail@mail.adobe.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "calendar-notification@google.com": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> IMPORTANT -> FROM -> SUBJECT",
#   "FROM -> DELETE -> FROM -> DELETE -> FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE -> FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE -> FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM",
#   "DELETE -> FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE -> FROM -> DELETE"
#  ],
#  "info@twitter.com": [
#   "SUBJECT -> ENGAGED",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "lwportraitscheduling@lifetouch.com": [
#   "FROM -> SUBJECT -> DATE -> ENGAGED -> OPEN -> CLOSED -> DURATION"
#  ],
#  "news@e.chobani.com": [
#   "FROM -> DELETE"
#  ],
#  "katespade@em.katespade.com": [
#   "FROM -> SUBJECT -> ENGAGED",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "ebay@reply.ebay.com": [
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "Lenovo@ecomms.lenovo.com": [
#   "FROM -> SUBJECT -> DATE -> DELETE",
#   "FROM",
#   "SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> ENGAGED",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM",
#   "DELETE"
#  ],
#  "targetnews@em.target.com": [
#   "FROM -> DATE -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED",
#   "DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM",
#   "DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "noreply@r.groupon.com": [
#   "FROM -> DATE -> SUBJECT",
#   "DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "YardHouse@e.yardhouse.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "news@bertuccis.fbmta.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "panera@e1.panerabread.com": [
#   "FROM",
#   "DELETE",
#   "FROM -> DELETE"
#  ],
#  "premium@academia-mail.com": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "newsletter@email.ticketmaster.com": [
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "newsletters@em.walmart.com": [
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "acme@deals.acmemarkets.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "communications@smgloyalty.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "mail@resy.com": [
#   "FROM",
#   "DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "no-reply@email.redbox.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "newsdigest@insideapple.apple.com": [
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "oldnavy@email.oldnavy.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM",
#   "DELETE",
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "noreply@medium.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "GiantFoodStores@email-giantfoodstores.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "mail@mail2.gofarrewards.wellsfargo.com": [
#   "FROM",
#   "OPEN -> CLOSED -> DURATION -> DELETE"
#  ],
#  "store-news@amazon.com": [
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "info@campusphilly.org": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "unilever@email.unilever.us": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "noreply@studentaid.gov": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT",
#   "FROM -> DELETE"
#  ],
#  "drexmail@drexel.edu": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> DELETE"
#  ],
#  "startuptree@noreply-startuptree.co": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "no-reply@piazza.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE",
#   "SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM",
#   "DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "adit@myvyb.io": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "js4677@drexel.edu": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY"
#  ],
#  "notification@facebookmail.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> ENGAGED",
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "auto-confirm@amazon.com": [
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM",
#   "DELETE"
#  ],
#  "discover@service.discover.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "thedanielschwartz@gmail.com": [
#   "FROM -> DELETE",
#   "DELETE"
#  ],
#  "bill@billmongan.com": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM",
#   "SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY"
#  ],
#  "TheCapitalGrille@e.thecapitalgrille.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "reccenter@drexel.edu": [
#   "FROM -> DELETE"
#  ],
#  "email@colonelsclub.kfc.com": [
#   "FROM -> DELETE"
#  ],
#  "reply@sendtax.hrblock.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "BedBath&Beyond@emailbedbathandbeyond.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "news@rubytuesdayrestaurants.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "hello@einsteinbros.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "SM457@bncollege.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "customer-reviews-messages@amazon.com": [
#   "FROM -> SUBJECT -> DELETE"
#  ],
#  "ba479@drexel.edu": [
#   "FROM -> SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> ENGAGED -> REPLY"
#  ],
#  "sierraclub@drexel.edu": [
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> DELETE",
#   "FROM -> SUBJECT -> DELETE"
#  ],
#  "shipment-tracking@amazon.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "chipotle@mktg-mail.chipotle.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "chestnutsquare@americancampus.com": [
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT",
#   "FROM -> SUBJECT -> IMPORTANT",
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> DELETE"
#  ],
#  "noreply@drexel.edu": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "thenorthface@explore.thenorthface.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "support@typeset.io": [
#   "FROM -> DELETE"
#  ],
#  "Texas_Roadhouse@texasr.fbmta.com": [
#   "FROM",
#   "DELETE",
#   "FROM -> DELETE",
#   "FROM",
#   "DELETE"
#  ],
#  "ek826@drexel.edu": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> FROM -> SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT",
#   "FROM -> SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT"
#  ],
#  "IC@cookie.love": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "ddperks@emails.dunkindonuts.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "acappetta@campusphilly.org": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "appstore@insideapple.apple.com": [
#   "FROM -> DELETE"
#  ],
#  "noreply@glassdoor.com": [
#   "FROM -> DELETE"
#  ],
#  "cciinfo@drexel.edu": [
#   "FROM -> SUBJECT -> IMPORTANT",
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> SUBJECT -> IMPORTANT"
#  ],
#  "orders@eventbrite.com": [
#   "FROM -> DELETE"
#  ],
#  "bathandbodyworks@e2.bathandbodyworks.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "donotreply@email.sweetgreen.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "no-reply@email.thetileapp.com": [
#   "FROM -> DELETE"
#  ],
#  "ashokouf@gmail.com": [
#   "FROM -> SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY"
#  ],
#  "dds26@drexel.edu": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY"
#  ],
#  "ewbmiramar@gmail.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "swe.drexel@gmail.com": [
#   "FROM -> DELETE",
#   "FROM",
#   "DELETE"
#  ],
#  "events@email-stubhub.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "noreply@eventbrite.com": [
#   "FROM -> SUBJECT -> DELETE",
#   "FROM",
#   "SUBJECT -> DELETE"
#  ],
#  "info@rungoapp.com": [
#   "FROM -> DELETE"
#  ],
#  "moerewards@moes.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "EddieVSPrimeSeafood@e.eddiev.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "honorsprogram@drexel.edu": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "info@meetup.com": [
#   "FROM -> DELETE"
#  ],
#  "pretzelperks@e.auntieannes.com": [
#   "FROM -> DELETE",
#   "FROM",
#   "DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "Rewards@saladworks.com": [
#   "FROM -> DELETE",
#   "FROM",
#   "DELETE"
#  ],
#  "return@amazon.com": [
#   "FROM -> DELETE -> FROM",
#   "DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE -> FROM -> DELETE"
#  ],
#  "arbys@arbys.fbmta.com": [
#   "FROM -> DELETE"
#  ],
#  "CCIInnovation@drexel.edu": [
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "BahamaBreeze@e.bahamabreeze.com": [
#   "FROM -> DELETE",
#   "FROM -> DATE -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "jobs-listings@linkedin.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "as79@drexel.edu": [
#   "FROM -> SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY"
#  ],
#  "rcp53@drexel.edu": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> IMPORTANT -> REPLY"
#  ],
#  "newsletter@traderjoes.com": [
#   "FROM -> DELETE"
#  ],
#  "noreply@marketing.lyftmail.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "drexelweekendwarriors@gmail.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "gkatz@drexel.edu": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT"
#  ],
#  "dragonsrundrexel@gmail.com": [
#   "FROM -> DELETE"
#  ],
#  "relay@relay.engage.campuslabs.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> DELETE",
#   "FROM",
#   "DELETE"
#  ],
#  "admin@osla.org": [
#   "FROM -> SUBJECT -> DELETE"
#  ],
#  "vb468@drexel.edu": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT"
#  ],
#  "eannounce@kimmelcenter.org": [
#   "FROM -> DELETE -> FROM",
#   "DELETE",
#   "FROM -> DELETE"
#  ],
#  "reply@email.livenation.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "smoothieking@e.smoothieking.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "newsletter@bdwayinfo.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "noreply@earnmoremall.gofarrewards.wellsfargo.com": [
#   "FROM -> DELETE"
#  ],
#  "no_reply@blazepizza.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "no-reply@m.mail.coursera.org": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "hsacdrexel@gmail.com": [
#   "FROM -> DATE -> DELETE"
#  ],
#  "notification@engage.jobvite.com": [
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> DELETE"
#  ],
#  "monster@emails.monster.com": [
#   "FROM -> DELETE",
#   "FROM",
#   "DELETE"
#  ],
#  "applepay@insideapple.apple.com": [
#   "FROM -> DELETE"
#  ],
#  "newsletter@news.anker.com": [
#   "FROM -> DELETE"
#  ],
#  "noreply@email.apple.com": [
#   "FROM -> DELETE"
#  ],
#  "kungfutea@levelup-mail.com": [
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> DELETE"
#  ],
#  "email@techsmith.messages4.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "support@bioraft.com": [
#   "FROM -> DELETE"
#  ],
#  "pj352@drexel.edu": [
#   "FROM -> SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY"
#  ],
#  "no-reply@enews.lifeproof.com": [
#   "FROM -> DELETE"
#  ],
#  "dcentral@drexel.edu": [
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT"
#  ],
#  "Walgreens@e.walgreens.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "email@mail.bose.com": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "drexelfund@drexel.edu": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "rewards@wawa-email.com": [
#   "FROM -> DELETE"
#  ],
#  "no-reply@sonicdrivein.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "yd362@drexel.edu": [
#   "FROM -> DELETE"
#  ],
#  "one@email.chick-fil-a.com": [
#   "FROM -> DELETE"
#  ],
#  "taco@trello.com": [
#   "FROM -> DELETE"
#  ],
#  "support@udacity.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "swdeluca@gmail.com": [
#   "FROM -> DELETE"
#  ],
#  "linkedin@e.linkedin.com": [
#   "FROM -> DELETE"
#  ],
#  "shoprunner@shoprunner.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "picks@eventbrite.com": [
#   "FROM -> DELETE"
#  ],
#  "hello@mail-6.hive.co": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "no-reply@mobirise.me": [
#   "FROM -> DELETE"
#  ],
#  "innovatela@aju.edu": [
#   "FROM -> DELETE"
#  ],
#  "katebeckman@ripplematch.com": [
#   "FROM -> DELETE"
#  ],
#  "marketing@getpostman.com": [
#   "FROM -> DELETE"
#  ],
#  "info@ripplematch.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "hackathons@devpost.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "digital-no-reply@broadwayroulette.com": [
#   "FROM -> DELETE"
#  ],
#  "moes@e.moes.com": [
#   "FROM -> DELETE"
#  ],
#  "Starbucks@e.starbucks.com": [
#   "FROM -> DELETE"
#  ],
#  "marketing@honeygrow.com": [
#   "FROM -> DELETE -> FROM -> DELETE"
#  ],
#  "fedexupdates@message.fedex.com": [
#   "FROM -> DELETE"
#  ],
#  "LongHorn@e.longhornsteakhouse.com": [
#   "FROM -> DELETE"
#  ],
#  "no-reply@researchgatemail.net": [
#   "FROM -> DELETE"
#  ],
#  "emailclub@jerseymikes.com": [
#   "FROM -> DELETE"
#  ],
#  "saxbysapp@saxbyscoffee.com": [
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "rewards@c.pxsmail.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "wak39@drexel.edu": [
#   "FROM -> DELETE"
#  ],
#  "savaspizza1@gmail.com": [
#   "FROM -> DELETE"
#  ],
#  "jdn29@drexel.edu": [
#   "FROM -> DELETE -> FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "venmo@venmo.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "developer@email.apple.com": [
#   "FROM -> DELETE"
#  ],
#  "contact@luckyseat.com": [
#   "FROM -> DELETE"
#  ],
#  "emails@visitphilly.com": [
#   "FROM -> DELETE"
#  ],
#  "donotreply@newsletter.rockstargames.com": [
#   "FROM -> DELETE"
#  ],
#  "news@shakeshack.com": [
#   "FROM -> DELETE"
#  ],
#  "saxbys@thelevelup.com": [
#   "FROM -> DELETE"
#  ],
#  "caf89@drexel.edu": [
#   "FROM -> SUBJECT -> DELETE"
#  ],
#  "payweb@drexel.edu": [
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "hello@e.eatmush.com": [
#   "FROM -> DELETE"
#  ],
#  "movies@movies.fandango.com": [
#   "FROM -> DATE -> DELETE"
#  ],
#  "invitation-do-not-reply@trello.com": [
#   "FROM -> SUBJECT",
#   "DELETE"
#  ],
#  "teamdragonhacks@gmail.com": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED"
#  ],
#  "no-reply@geeksforgeeks.org": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "lizp@philadelphiarunner.com": [
#   "FROM -> DELETE"
#  ],
#  "CCIRoom1116@drexel.edu": [
#   "FROM -> DELETE"
#  ],
#  "contact@hello.webflow.com": [
#   "FROM -> DELETE"
#  ],
#  "vasileios.gkatzelis@drexel.edu": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT"
#  ],
#  "mso@drexel.edu": [
#   "FROM -> DELETE"
#  ],
#  "feedback@slack.com": [
#   "FROM -> SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> ENGAGED",
#   "FROM -> DELETE"
#  ],
#  "kab356@drexel.edu": [
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "email@a.grubhub.com": [
#   "FROM -> DELETE"
#  ],
#  "osla@public.govdelivery.com": [
#   "FROM -> DELETE"
#  ],
#  "noreply@github.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> DELETE"
#  ],
#  "answers@amazon.com": [
#   "FROM -> DATE -> DELETE"
#  ],
#  "info@ouryear.com": [
#   "FROM -> DELETE",
#   "FROM -> SUBJECT -> DELETE"
#  ],
#  "hello@team.hillcity.com": [
#   "FROM -> DELETE"
#  ],
#  "builds@travis-ci.com": [
#   "FROM -> DELETE",
#   "FROM -> DELETE"
#  ],
#  "po73@drexel.edu": [
#   "FROM -> SUBJECT",
#   "OPEN -> CLOSED -> DURATION -> IMPORTANT -> REPLY"
#  ],
#  "admin@wedado.com": [
#   "FROM -> DELETE"
#  ],
#  "email@wawa-email.com": [
#   "FROM -> DELETE"
#  ],
#  "offer@pancherosmarltonnj.com": [
#   "FROM -> DELETE"
#  ],
#  "enroll@drexel.edu": [
#   "FROM -> SUBJECT -> DELETE",
#   "FROM -> SUBJECT -> DELETE"
#  ],
#  "wta24@drexel.edu": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT",
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY"
#  ],
#  "support@codepen.io": [
#   "FROM -> DELETE"
#  ],
#  "mt3223@drexel.edu": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY"
#  ],
#  "handshake@notifications.joinhandshake.com": [
#   "FROM -> DELETE -> FROM -> DELETE"
#  ],
#  "news-noreply@linkedin.com": [
#   "FROM -> DELETE"
#  ],
#  "skessler@lifetouch.com": [
#   "FROM -> SUBJECT -> OPEN -> CLOSED -> DURATION -> ENGAGED -> IMPORTANT -> REPLY"
#  ],
#  "goodwin.ce@drexel.edu": [
#   "FROM -> SUBJECT -> DELETE"
#  ],
#  "des338@drexel.edu": [
#   "FROM -> DELETE"
#  ]
# }

# %%
def calculate_probabilities(actions):
    count = len(actions)

    hist_freq = {}
    hist_discounted = {}
    weighted_probability = {}

    for idx, action in enumerate(actions):
        hist_freq = calculate_histogram(hist_freq, action)
        hist_discounted = calculate_discounted_histogram(hist_discounted, action, idx, count)  

    for action in list(dict.fromkeys(actions)):
        weighted_probability[action] = hist_freq[action] + hist_discounted[action]

    normalized_weighted_probability = calculate_normalized_histogram(weighted_probability)
    return normalized_weighted_probability



def calculate_histogram(prev_hist, action):
    if action in prev_hist:
        prev_hist[action] += 1
    else:
        prev_hist[action] = 1
    return prev_hist

def calculate_discounted_histogram(prev_hist, action, loc, total):
    weight = (loc+1) / total

    if action in prev_hist:
        prev_hist[action] += weight
    else:
        prev_hist[action] = weight
    return prev_hist

def calculate_normalized_histogram(hist):
    total_count = sum(hist.values())
    normalized_hist = {}

    for action, freq in hist.items():
        normalized_hist[action] = freq / total_count

    return normalized_hist

# %%
def classify(predicted_distribution):
    max_k = None
    max_v = 0
    
    for k, v in predicted_distribution.items():
        if v > 0.5:
            return k
        if v > max_v:
            max_v = v
            max_k = k
    return max_k

# %%
def classify_rest_emails(example, starting_index=1):
    total_correct = 0
    total_classified = 0
    total_wrong = 0
    
    for i in range(starting_index, len(example)):
        train_example = example[:i]
        predicted_distribution = calculate_probabilities(train_example)
        classified_result = classify(predicted_distribution)
        
        ## Check if classified result is correct
        # print("{} == {}".format(classified_result, example[i]))
        total_classified += 1
        if classified_result == example[i]:
            total_correct += 1
        else:
            total_wrong += 1
    
    return total_classified, total_correct, total_wrong

# %%
def classify_all_senders(senders, history):
    classified_senders = 0
    correct_senders = 0
    wrong_senders = 0
    
    classify_senders = {}
    for sender in senders:
        if len(senders[sender]) > history + 1:
            classified_senders += 1
            classify_senders[sender] = senders[sender]

    total_classified = 0
    total_correct = 0
    total_wrong = 0

    for sender in classify_senders:
        count, corr, wrong = classify_rest_emails(classify_senders[sender], history)
        total_classified += count
        total_correct += corr
        total_wrong += wrong
        
        if corr == count:
            correct_senders += 1
        elif wrong == count:
            wrong_senders += 1
            
        
    return total_classified, total_correct, total_wrong, classified_senders, correct_senders, wrong_senders

# %%
for i in range(10):
    total_classified, total_correct, total_wrong, classified_senders, correct_senders, wrong_senders = classify_all_senders(senders,i)
    print("\nUsing History No. {}".format(i))
    print("Accuracy: {0:10.4f}".format(total_correct / total_classified))
    print("Completely Correct: {0:10.4f}".format(correct_senders / classified_senders))
    print("Completely Incorrect: {0:10.4f}".format(wrong_senders / classified_senders))
#     print("Total: {}\nCorrect: {}\nWrong: {}".format(total_classified, total_correct, total_wrong))
# Out:
# Using History No. 0
# Accuracy:     0.5976
# Completely Correct:     0.0000
# Completely Incorrect:     0.2627
#
# Using History No. 1
# Accuracy:     0.7361
# Completely Correct:     0.3514
# Completely Incorrect:     0.1892
#
# Using History No. 2
# Accuracy:     0.7946
# Completely Correct:     0.3958
# Completely Incorrect:     0.1042
#
# Using History No. 3
# Accuracy:     0.8242
# Completely Correct:     0.4359
# Completely Incorrect:     0.1026
#
# Using History No. 4
# Accuracy:     0.8605
# Completely Correct:     0.5625
# Completely Incorrect:     0.0312
#
# Using History No. 5
# Accuracy:     0.8593
# Completely Correct:     0.5385
# Completely Incorrect:     0.0000
#
# Using History No. 6
# Accuracy:     0.8462
# Completely Correct:     0.5217
# Completely Incorrect:     0.0435
#
# Using History No. 7
# Accuracy:     0.8373
# Completely Correct:     0.5238
# Completely Incorrect:     0.0476
#
# Using History No. 8
# Accuracy:     0.8315
# Completely Correct:     0.4706
# Completely Incorrect:     0.0588
#
# Using History No. 9
# Accuracy:     0.8323
# Completely Correct:     0.5294
# Completely Incorrect:     0.0588
